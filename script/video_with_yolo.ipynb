# %%
from utils.yolo_detector import yolo_video

in_path  = f"../input/video_group_11_dynamic.mp4"

blacklist = ['person', 'skateboard', 'laptop', 'cup', 'chair', 'dining table', 'microwave', 'umbrella', 
    'kite', 'cat', 'traffic light', 'book', 'cell phone', 'keyboard', 'scissors', 'frisbee', 'suitcase', 'dog', 'tv']

yolo_video(in_path, read_every_x_frame=5, blacklist=blacklist, confidence_threshold=0.0)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from utils.yolo_detector import yolo_video
#       3 in_path  = f"../input/video_group_11_dynamic.mp4"
#       5 blacklist = ['person', 'skateboard', 'laptop', 'cup', 'chair', 'dining table', 'microwave', 'umbrella',
#       6     'kite', 'cat', 'traffic light', 'book', 'cell phone', 'keyboard', 'scissors', 'frisbee', 'suitcase', 'dog', 'tv']
#
# File d:\DOCUMENTS\UNIF\repository\Computer_Vision\script\utils\yolo_detector.py:4
#       2 import cv2
#       3 import numpy as np
# ----> 4 from ..CONFIG import *
#       5 from .box import xyxy_to_cxcywh, draw_box
#       6 from ultralytics import YOLO
#
# ImportError: attempted relative import beyond top-level package

# %%
from utils.yolo import annotate_video

# for i in [1, 3, 4, 5, 6, 8, 9, 10, 11, 12]:

#     print(f"-----------------{i} fixed-------------------")
#     in_path  = f"../input/video_group_{i}_fixed.mp4"
#     annotate_video(in_path, read_every_x_frame=5, out_path=None, confidence_threshold=0.0)

for i in [1, 3, 4, 5, 6, 8, 9, 10, 11, 12]:

    print(f"-----------------{i} dynamic-------------------")
    in_path  = f"../input/video_group_{i}_dynamic.mp4"
    annotate_video(in_path, read_every_x_frame=5, out_path=None, confidence_threshold=0.0)

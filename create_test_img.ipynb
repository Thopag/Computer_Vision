# %%
import cv2
import numpy as np

# %%
img = np.zeros((100,100)) 

img[40:60, 40:60] = 255

filename = "test_img/center_square.png"
cv2.imwrite(filename, img)
# Out:
# True

# %%
img = np.zeros((100,100)) 

img[30:70, 30:70] = 255

filename = "test_img/big_center_square.png"
cv2.imwrite(filename, img)
# Out:
# True

# %%
img = np.zeros((100,100)) 

img[30:70, 30:70] = 255
img[10:20, 5:15] = 255
img[60:70, 80:95] = 255


filename = "test_img/big_noisy_center_square.png"
cv2.imwrite(filename, img)
# Out:
# True

# %%
img = np.zeros((100,100)) 

img[10:30, 50:70] = 255

filename = "test_img/on_side_square.png"
cv2.imwrite(filename, img)
# Out:
# True

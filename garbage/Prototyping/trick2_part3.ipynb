# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt
from utils.yolo import *
from utils.video import *
from utils.color import *
from utils.ROI import * 
import os
import json
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
in_path  = "data/splits_fixed/trick_2.mp4"
out_path = "output/trick_2_output001.mp4"

# %%
frame = cv2.imread("data/04.png")
plt.imshow( cv2.cvtColor(frame ,cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
masks, labels = detect_objects(frame)
# Out:
# 0: 416x640 1 sports ball, 1 bottle, 86.6ms
# Speed: 15.7ms preprocess, 86.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)

# %%
plt.imshow(masks[0], cmap='gray')
plt.axis('off')
plt.show()
